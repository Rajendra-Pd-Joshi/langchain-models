# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_16004\3278018332.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
search_tool = DuckDuckGoSearchRun()

# %%
search_tool.invoke('current news about sudan gurung?')
# Out:
# "5 hours ago · sudan gurung Latest Breaking News, Pictures, Videos, and Special Reports from The Economic Times. sudan gurung Blogs, Comments and Archive News on Economictimes.com Sep 14, 2025 · Sudan Gurung's press conference in Kathmandu turned chaotic after his supporter assaulted a journalist, leading to a violent backlash and calls for Gurung's apology amid ongoing nationwide protests. 1 day ago · KATHMANDU: Home Minister Sudan Gurung has resigned from his post amid growing criticism over alleged business links and share transactions with controversial businessmen. Gurung submitted his resignation to Prime Minister Balendra Shah (Balen) and also made the announcement public through social media. Prime Minister Shah had appointed Gurung as Home Minister on the same day […] Sep 14, 2025 · Find Sudan Gurung Latest News, Videos & Pictures on Sudan Gurung and see latest updates, news, information from NDTV.COM. Explore more on Sudan Gurung. Sep 9, 2025 · Sudan Gurung, president of youth NGO Hami Nepal, emerges as the face of nationwide protests over social media restrictions. With at least 20 dead and hundreds injured, Nepal’s PM resigns, while Gen-Z rallies behind Gurung demanding transparency, freedom, and change."

# %%
llm = ChatOpenAI()

# %%
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

# %%
agent = create_agent(
    model = llm,
    tools=[search_tool],
    system_prompt='you are a helpful assistant'
)

# %%
response = agent.invoke({
    'messages':[
        HumanMessage(content='who is the home minister of nepal and current news about him?')
    ]
})

# %%
response
# Out:
# {'messages': [HumanMessage(content='who is the home minister of nepal and current news about him?', additional_kwargs={}, response_metadata={}, id='7265af9a-36f2-4bdb-8e91-e3906f19948c'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 96, 'total_tokens': 117, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 7.95e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 7.95e-05, 'upstream_inference_prompt_cost': 4.8e-05, 'upstream_inference_completions_cost': 3.15e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-3.5-turbo', 'system_fingerprint': None, 'id': 'gen-1783397071-EU2iuKnJ95fc6uuRJsJd', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f3abf-bbbf-7c73-a5e7-a208e00d8000-0', tool_calls=[{'name': 'duckduckgo_search', 'args': {'query': 'current Home Minister of Nepal'}, 'id': 'call_azl8dGFGqO2fdFQQZLY1NudX', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 21, 'total_tokens': 117, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="The Minister of Home Affairs (Nepali: गृहमन्त्री, romanized: Gṛha Mantrī; or simply, the Home Minister) is the head of the Ministry of Home Affairs of the Government of Nepal. One of the senior-most officers in the Federal Cabinet, the chiefCurrent events. Random article. Government of Nepal. Ministry of Home Affairs. Search website content. Tuesday, Ashadh 16, 2083 04:30. Discover insights into the current Home Minister of Nepal, Om Prakash Aryal, and his impact on governance. #trending. Nepal's newly appointed Home Minister Sudan Gurung (in black cap) chairs a meeting at the ministry in Kathmandu, Nepal, on March 27, 2026. Nepal's home minister stepped down Wednesday over growing criticism of his finances, the second member of the cabinet to leave the new government just weeks after it was formed.", name='duckduckgo_search', id='25c1b4e3-711a-4d7c-b309-8046263588ef', tool_call_id='call_azl8dGFGqO2fdFQQZLY1NudX'),
#   AIMessage(content='The current Home Minister of Nepal is Sudan Gurung. He recently stepped down from his position due to growing criticism of his finances.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 324, 'total_tokens': 351, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 0.0002025, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 0.0002025, 'upstream_inference_prompt_cost': 0.000162, 'upstream_inference_completions_cost': 4.05e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-3.5-turbo', 'system_fingerprint': None, 'id': 'gen-1783397077-ntpKDsWOLtDXsBJECL8G', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3abf-d5a1-75c0-a8e6-451b9393be39-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 324, 'output_tokens': 27, 'total_tokens': 351, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
response['messages'][-1].content
# Out:
# 'The current Home Minister of Nepal is Sudan Gurung. He recently stepped down from his position due to growing criticism of his finances.'

# %% [markdown]
# #### 3 step process (thought,action and observation) loop continues
