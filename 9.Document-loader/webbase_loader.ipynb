# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
url = 'https://www.flipkart.com/apple-macbook-air-m2-8-gb-512-gb-ssd-mac-os-monterey-mlxx3hn-a/p/itmc2732c112aeb1?pid=COMGFB2GNWNN9DN8&lid=LSTCOMGFB2GNWNN9DN8OLT676&marketplace=FLIPKART&q=macbook+air&store=6bo%2Fb5g&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=b6265f7f-16d7-471b-96fe-97f09df5240b.COMGFB2GNWNN9DN8.SEARCH&ppt=hp&ppn=homepage&ssid=59dc9d9su80000001782562903682&qH=b61d62051d5441f9&ov_redirect=true'
Loader = WebBaseLoader(url)

# %%
documents = Loader.load()

# %%
len(documents)
print(documents[0].page_content)
